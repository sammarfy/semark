# %%
import torch
assert torch.cuda.is_available(), 'Set runtime to T4 GPU (Runtime → Change runtime type).'
print('GPU:', torch.cuda.get_device_name(0), '| torch', torch.__version__)
# Out:
# GPU: Tesla T4 | torch 2.11.0+cu128
